# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=pd.read_excel(r"C:\Users\rajla\Desktop\IRIM\nss_irim_siscomb_new2018_han.xlsx")

# %%
df.head()
# Out:
#    ACADEMIC_PERIOD  PERSON_UID         ID BIRTH_DATE IRIM_SC_PRI_COLLEGE  \
# 0           201860      713886  A11538436 1994-02-23                  SB
# 1           201860      748099  A11584552 1993-06-16                  EN
# 2           201860      769414  A11609331 1994-10-25                  AS
# 3           201860      779624  A11621467 1999-07-12                  EN
# 4           201860      825552  A11677138 1999-11-17                  UC
#
#   IRIM_SC_PRI_DEGREE IRIM_SC_PRI_MAJOR IRIM_SC_PRI_FIRST_CONC  \
# 0               BSBA              MKTG                    NaN
# 1               BSAE              AERS                    NaN
# 2                 BS              ZOOL                    NaN
# 3               BSCH              CHEN                   PMED
# 4                  B               UND                    NaN
#
#   IRIM_SC_PRI_PROGRAM GENDER  ... SORGPAT_GPA T2_ENROLLED T3_ENROLLED  \
# 0         SB BSBAMKTG      F  ...        3.09           1           0
# ...

# %%
df.columns.get_loc("IRIM_REPORTED_RACE_DESC")
# Out:
# 11

# %%
df.shape
# Out:
# (3096, 149)

# %%
df.drop(df.columns[[0, 2,3,4,5,6,7,8,10,11,12,13,16,145,144,142,141]],axis=1, inplace=True)

# %%
df.shape
# Out:
# (3096, 132)

# %%
df1=df.drop(df.loc[:,'HS_STUDY_DESC':'TERM_3'].columns,axis=1)

# %%
df1.shape
# Out:
# (3096, 96)

# %%
df2= df1.drop(df.loc[:,'T2_GPA_CREDITS':'SUPER_ACT_FROM_SATR'].columns, axis=1)

# %%
df2.shape
# Out:
# (3096, 57)

# %%
#df2.head()

# %%
df2.isna().sum()
# Out:
# PERSON_UID                 0
# GENDER                     1
# IRIM_FIRST_GEN_FLAG        0
# IRIM_LEGACY_FLAG           0
# HS_STUDY                   0
# OSU_STUDY                  0
# DIFFICULTY_01              0
# DIFFICULTY_02              0
# DIFFICULTY_03              0
# DIFFICULTY_04              0
# DIFFICULTY_05              0
# DIFFICULTY_06              0
# DIFFICULTY_07              0
# DIFFICULTY_08              0
# DIFFICULTY_09              0
# DIFFICULTY_10              0
# CONFIDENCY                 0
# ANT_GPA                    0
# HS_ACTIVITY_01             0
# HS_ACTIVITY_02             0
# HS_ACTIVITY_03             0
# HS_ACTIVITY_04             0
# HS_ACTIVITY_05             0
# RS_01                     10
# RS_02                     10
# RS_03                     10
# RS_04                     10
# RS_05                     10
# RS_06                     10
# RS_07                     10
# RS_08                     10
# RS_09                     10
# ...

# %%
#df3=df2.dropna(subset=['GENDER'])

# %%
df3=df2.dropna()

# %%
df3.isna().sum()
# Out:
# PERSON_UID               0
# GENDER                   0
# IRIM_FIRST_GEN_FLAG      0
# IRIM_LEGACY_FLAG         0
# HS_STUDY                 0
# OSU_STUDY                0
# DIFFICULTY_01            0
# DIFFICULTY_02            0
# DIFFICULTY_03            0
# DIFFICULTY_04            0
# DIFFICULTY_05            0
# DIFFICULTY_06            0
# DIFFICULTY_07            0
# DIFFICULTY_08            0
# DIFFICULTY_09            0
# DIFFICULTY_10            0
# CONFIDENCY               0
# ANT_GPA                  0
# HS_ACTIVITY_01           0
# HS_ACTIVITY_02           0
# HS_ACTIVITY_03           0
# HS_ACTIVITY_04           0
# HS_ACTIVITY_05           0
# RS_01                    0
# RS_02                    0
# RS_03                    0
# RS_04                    0
# RS_05                    0
# RS_06                    0
# RS_07                    0
# RS_08                    0
# RS_09                    0
# RS_10                    0
# RS_11                    0
# ...

# %%
df3.head()
# Out:
#    PERSON_UID GENDER IRIM_FIRST_GEN_FLAG IRIM_LEGACY_FLAG  HS_STUDY  \
# 0      713886      F                   Y                N         2
# 1      748099      F                   N                N         3
# 3      779624      F                   N                N         1
# 4      825552      F                   N                N         2
# 5      832176      M                   N                N         1
#
#    OSU_STUDY  DIFFICULTY_01  DIFFICULTY_02  DIFFICULTY_03  DIFFICULTY_04  ...  \
# 0          4              4              2              4              4  ...
# 1          4              2              2              3              2  ...
# 3          3              3              2              2              2  ...
# 4          3              4              3              3              2  ...
# 5          3              3              2              2              4  ...
#
#    ET_QUALITY_POINTS    T2_GPA  HIGHEST_ACT_COMPOSITE  ACT_COMPOSITE_SUPER  \
# ...

# %%
df3.describe()
# Out:
#          PERSON_UID     HS_STUDY    OSU_STUDY  DIFFICULTY_01  DIFFICULTY_02  \
# count  2.820000e+03  2820.000000  2820.000000    2820.000000    2820.000000
# mean   1.137853e+06     1.578014     2.963475       3.211702       3.007092
# std    3.923428e+04     0.774697     0.756487       1.015072       0.950319
# min    7.138860e+05     1.000000     1.000000       1.000000       1.000000
# 25%    1.135252e+06     1.000000     2.000000       3.000000       2.000000
# 50%    1.142556e+06     1.000000     3.000000       3.000000       3.000000
# 75%    1.153157e+06     2.000000     3.000000       4.000000       4.000000
# max    1.187563e+06     5.000000     5.000000       5.000000       5.000000
#
#        DIFFICULTY_03  DIFFICULTY_04  DIFFICULTY_05  DIFFICULTY_06  \
# count    2820.000000    2820.000000    2820.000000    2820.000000
# mean        3.147518       3.355319       2.990426       3.669504
# std         0.874257       1.031255       1.187128       1.031600
# ...

# %%
#Data Visualization
#college_counts=df3['IRIM_SC_PRI_DEGREE'].value_counts()
#college_counts.plot(kind='bar')
#Degree_counts = df3['IRIM_SC_PRI_MAJOR'].value_counts()
#Degree_counts.plot(kind='bar')

# %%
#df.plot(kind='bar' )
#plt.show()

# %%
#scatter_matrix(df2)
#plt.show()

# %%
df3.groupby('GENDER').size()
# Out:
# GENDER
# F    1538
# M    1282
# dtype: int64

# %%
df3.groupby('T2_ENROLLED').size()
# Out:
# T2_ENROLLED
# 0       3
# 1    2817
# dtype: int64

# %%
#df3.groupby('FALL_UA_ATTR1').size()

# %%
df3['GENDER']=df3['GENDER'].map({'F':1,'M':0})
df3['IRIM_FIRST_GEN_FLAG']=df3['IRIM_FIRST_GEN_FLAG'].map({'Y':1,'N':0})
df3['IRIM_LEGACY_FLAG']=df3['IRIM_LEGACY_FLAG'].map({'Y':1,'N':0})
df3['TERM_RESIDENCY1']=df3['TERM_RESIDENCY1'].map({'R':1,'N':0})
df3['FALL_UA_ATTR1']=df3['FALL_UA_ATTR1'].map({'Y':1,'N':0})
# Out:
# C:\Users\rajla\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\rajla\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\rajla\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df3.head()
# Out:
#    PERSON_UID  GENDER  IRIM_FIRST_GEN_FLAG  IRIM_LEGACY_FLAG  HS_STUDY  \
# 0      713886       1                    1                 0         2
# 1      748099       1                    0                 0         3
# 3      779624       1                    0                 0         1
# 4      825552       1                    0                 0         2
# 5      832176       0                    0                 0         1
#
#    OSU_STUDY  DIFFICULTY_01  DIFFICULTY_02  DIFFICULTY_03  DIFFICULTY_04  ...  \
# 0          4              4              2              4              4  ...
# 1          4              2              2              3              2  ...
# 3          3              3              2              2              2  ...
# 4          3              4              3              3              2  ...
# 5          3              3              2              2              4  ...
#
# ...

# %%
df3.groupby('GENDER').size()
# Out:
# GENDER
# 0    1282
# 1    1538
# dtype: int64

# %%
#Modeling
from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold

# %%
df3.columns.get_loc("T2_ENROLLED")
# Out:
# 52

# %%
#Cat_var=df3[['IRIM_SC_PRI_COLLEGE','IRIM_SC_PRI_DEGREE','IRIM_SC_PRI_MAJOR','GENDER','IRIM_REPORTED_RACE_DESC',
 #                        'IRIM_FIRST_GEN_FLAG','IRIM_LEGACY_FLAG','TERM_RESIDENCY1','FALL_UA_ATTR1']]

# %%
#dummies=pd.get_dummies(data=Cat_var,drop_first=True)

# %%
#dummies.head()

# %%
#dummies.columns

# %%
#split dataset
array=df3.values
X=array[:,1:52]
y=array[:,52]

# %%
X_train,X_validation,y_train,y_validation=model_selection.train_test_split(X,y,test_size=0.20,random_state=7)

# %%
seed=7
scoring='accuracy'
models = []
models.append(('LR',LogisticRegression(solver='liblinear',multi_class='ovr')))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('NB',GaussianNB()))
models.append(('SVM',SVC(gamma='auto')))

# %%
#Evaluate each model in turn
results =[]
names = []
for name, model in models:
    results = []
names = []
for name , model in models:
    kfold=model_selection.KFold(n_splits=10,random_state=seed)
    cv_results = model_selection.cross_val_score(model, X_train,y_train, cv= kfold,scoring =scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name,cv_results.mean(),cv_results.std())
    #msg = (f'{name} {cv_results.mean()} {cv_results.std()}')
    print(msg)
# Out:
# LR: 0.998228 (0.002170)
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# C:\Users\rajla\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
# ...
